# %% [markdown]
# # Kanawat Vilasri
# > site web personnel

# %% [markdown]
# <a href="https://github.com/gri11">
# <img id="githubImage" src="https://cdn-icons-png.flaticon.com/512/25/25231.png" alt="GitHub" width="50" height="50" style="cursor: pointer;">
# </a>
# <img id="emailImage" src="https://cdn-icons-png.flaticon.com/512/542/542638.png" alt="Email" width="50" height="50" style="cursor: pointer;">
#
# <div id="emailText" style="display: none;">
# kanawatgrill2002 __at__ gmail.com
# </div>
#
# <script>
# document.getElementById("emailImage").addEventListener("click", function() {
#     document.getElementById("emailText").style.display = "block";
# });
# </script>

# %%
print('hello world')
# Out:
# hello world
